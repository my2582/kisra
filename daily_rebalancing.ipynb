# %%
import numpy as np
import pandas as pd
from datetime import datetime
from src.models.load_data import Balance, Instruments, AdvisedPortfolios, PriceDB, Singleton

# %%
detail = pd.read_pickle('./data/processed/balance_s.pkl')
advised_pf = pd.read_pickle('./data/processed/advised_portfolios.pkl')

# %%
advised_pf.loc[(advised_pf.date=='2021-04-30')&(advised_pf.risk_profile==4), :]
# Out:
#              date  risk_profile itemcode  weights tracking_code  \
# 19382  2021-04-30             4  A157490    0.240            SW
# 19383  2021-04-30             4  A237370    0.240   BAL_KO3KTB7
# 19384  2021-04-30             4  A278540    0.240       MSCI_KR
# 19385  2021-04-30             4  A266370    0.136            IT
# 19386  2021-04-30             4  A292150    0.084         TOP10
# 19387  2021-04-30             4  A114260    0.060        KTB_D3
#
#                   itemname    price    volume  trading_amt_mln   asset_class
# 19382          TIGER 소프트웨어  16730.0  126257.0      2628.488604        Equity
# 19383       KODEX 배당성장채권혼합  12060.0    5299.0       123.076578   Alternative
# 19384  KODEX MSCI Korea TR  13695.0  471792.0     14353.562789        Equity
# 19385             KODEX IT  20760.0   21069.0      1087.656470        Equity
# 19386          TIGER TOP10  14305.0  547411.0     14890.029898        Equity
# 19387          KODEX 국고채3년  58040.0    5351.0       938.070000  Fixed Income

# %%
detail = detail.loc[detail.date=='3/22/2021 4:00:00 PM',:]

# %%
current_date='2021-03-22'
risk_profile = 4
userid='A008'
username='적극투자형중규모'

# %%
rebal_dates = advised_pf.loc[(advised_pf.risk_profile == 4) & (
        advised_pf.date > current_date), 'date'].min()
dt = rebal_dates

# %%
from pypfopt.discrete_allocation import DiscreteAllocation

# %%
def run_simulation(first_trade=False, new_units=None, prices=None, remaining_cash=None):
    price_db = PriceDB.instance().data

    # 최근 잔고 가져오기
    # 아직 어떤 타입으로 가져오는지 모름
    #detail = self.db.getUserBalance(userid=self.userid)       
    #detail = pd.DataFrame(detail, columns=['date', 'userid', 'name', 'asset_class', 'itemcode', 'itemname',
#                                            'quantity', 'cost_price', 'cost_value', 'price', 'value', 'wt', 'group_by', 'original'])

    # 시뮬레이션 기간은 현재일(current_date) 다음 날부터 추천 포트폴리오가 존재하는 마지막날까지임.
    dates = advised_pf.loc[(advised_pf.risk_profile == risk_profile) & (
        advised_pf.date > current_date), 'date'].min()
    rebal_dates = dates
    print('리밸런싱 일자: ', rebal_dates)

    # return할 때 필요한 첫날의 추천 포트 폴리오와 asset class별 정보 수집
    new_port = advised_pf.loc[(advised_pf.date == rebal_dates) & (
        advised_pf.risk_profile == risk_profile), :]

    first_advised_port = new_port.loc[:, ['weights', 'itemname', 'itemcode']].groupby(
        ['itemname', 'itemcode']).sum().reset_index()
    by_assetclass = new_port.loc[:, ['weights', 'asset_class']].groupby(
        'asset_class').sum().sort_values('weights', ascending=False).reset_index()


    # next_detail = copy.deepcopy(detail)
    next_detail = detail
    all_the_nexts = pd.DataFrame(columns=next_detail.columns)
    nexts_list = []
    price_db = price_db.loc[:, ['date', 'price', 'itemcode']]
    price_d = price_db.loc[price_db.date==dt, ['date', 'price', 'itemcode']]

    # 리밸런싱한다.
    new_port = advised_pf.loc[(advised_pf.risk_profile==risk_profile) & (advised_pf.date==dt), ['date', 'itemcode', 'weights', 'itemname', 'price', 'asset_class']]
    next_detail = rebalance(rebal_date=dt, price_d=price_d, detail=next_detail, new_port=new_port)

    # all_the_nexts = pd.concat((all_the_nexts, next_detail))
    nexts_list.append(next_detail)

    all_the_nexts = pd.concat(nexts_list, axis=0)

    print('리밸런싱 종료----')
    # 불필요한 컬럼 및 행 삭제
    all_the_nexts = all_the_nexts.loc[all_the_nexts.quantity > 0]
    all_the_nexts = all_the_nexts.reset_index(drop=True)
    all_the_nexts['username'] = username

    all_the_generals = all_the_nexts.loc[:,['date', 'wt', 'value', 'asset_class']].sort_values(
                                      ['date'], ascending=True).groupby([
                                          'date', 'asset_class'
                                      ]).sum().reset_index(drop=False)
    print('자산군별 요약 계산 종료----')

    all_the_generals['userid'] = userid

    return first_advised_port, by_assetclass, all_the_nexts, all_the_generals

# %%
def rebalance(rebal_date, price_d, detail, new_port):
    '''
    Rebalance a portfolio.

    Parameters:
    rebal_date: str
        rebalancing date

    detail: DataFrame
    current balance

    price_d: DataFrame
    price data on rebal_date

    new_port: DataFrame
    A new portfolio. Your current portfolio in `detail` will be rebalanced toward `new_port`.
    '''
    trading_amt = detail.value.sum()       

    wt = new_port[['itemcode', 'weights']].set_index('itemcode').to_dict()['weights']
    pr = new_port[['itemcode', 'price']].set_index('itemcode').squeeze()

    da = DiscreteAllocation(weights=wt, latest_prices=pr, total_portfolio_value=trading_amt)

    allocation, remaining_cash = da.greedy_portfolio()
    print("리밸런싱 결과:")
    print("{}: 새 포트폴리오(종목코드:수량)-{}".format(rebal_date,allocation))
    print(" - 매매 후 잔액: {:.2f} KRW".format(remaining_cash))

    # 매매한 뒤의 레코드 생성
    df_qty = pd.DataFrame.from_dict(allocation, orient='index', columns=['quantity'])
    next_detail = new_port.merge(df_qty, left_on='itemcode', right_index=True, how='inner')
    next_detail['cost_price'] = next_detail.price.copy()   
    next_detail['cost_value'] = next_detail.cost_price*next_detail.quantity
    next_detail['value'] = next_detail.cost_value.copy()

    # 매매하고 남은 돈은 현금으로
    df_cash = {
        'itemcode': 'C000001',
        'quantity': remaining_cash,
        'cost_price': 1,
        'price':1,
        'cost_value': remaining_cash,
        'value': remaining_cash,
        'itemname': '현금',
        'asset_class': 'Cash'
    }
    df_cash = pd.DataFrame.from_dict(df_cash, orient='index').T

    next_detail = pd.concat((next_detail[['itemcode', 'quantity', 'cost_price', 'price', 'cost_value', 'value',
    'itemname', 'asset_class']], df_cash), axis=0)

    next_detail['wt'] = next_detail.value/next_detail.value.sum()
    next_date = datetime.strptime(rebal_date, '%Y-%m-%d')
    #next_date = str(next_date.month)+'/'+str(next_date.day)+'/'+str(next_date.year)+' 03:30:00 PM'
    next_detail['date'] = next_date
    next_detail.reset_index(drop=True, inplace=True)
    next_detail['group_by'] = ''
    next_detail = pd.merge(next_detail,
            price_d.loc[price_d.date==rebal_date, ['date', 'itemcode']],
            left_on=['date', 'itemcode'],
            right_on=['date', 'itemcode'], how='left')
    next_detail['username'] = username
    next_detail['userid'] = userid
    next_detail['original'] = 'Rebal'
    next_detail = next_detail.rename(columns={'weights':'wt'})
    next_detail = next_detail[['itemcode', 'quantity', 'cost_price', 'price', 'cost_value', 'value',
        'itemname', 'asset_class', 'date', 'userid', 'username', 'group_by',
        'original', 'wt']]

    return next_detail

# %%
first_advised_port, by_assetclass, all_the_nexts, all_the_generals = run_simulation()
# Out:
# 리밸런싱 일자:  2021-03-23
# 리밸런싱 결과:
# 2021-03-23: 새 포트폴리오(종목코드:수량)-{'A237370': 14, 'A157490': 10, 'A278540': 12, 'A266370': 5, 'A292150': 4, 'A114260': 1}
#  - 매매 후 잔액: 7138.75 KRW
# 리밸런싱 종료----
# 자산군별 요약 계산 종료----

# %%
first_advised_port
# Out:
#               itemname itemcode  weights
# 0             KODEX IT  A266370    0.136
# 1  KODEX MSCI Korea TR  A278540    0.240
# 2          KODEX 국고채3년  A114260    0.060
# 3       KODEX 배당성장채권혼합  A237370    0.240
# 4          TIGER TOP10  A292150    0.084
# 5          TIGER 소프트웨어  A157490    0.240

# %%
before = detail.loc[detail.date=='3/22/2021 4:00:00 PM',:]
after = all_the_nexts

# %%
after = after.merge(first_advised_port.loc[:, ['itemcode', 'weights']], left_on='itemcode', right_on='itemcode', how='left')

# %%
after.weights = after.weights.fillna(0)

# %%
after = after.rename(columns={'weights':'mp_wt'})

# %%
after
# Out:
#   itemcode quantity cost_price  price cost_value    value  \
# 0  A237370       14      11720  11720     164080   164080
# 1  A157490       10      16850  16850     168500   168500
# 2  A278540       12      13290  13290     159480   159480
# 3  A266370        5      20795  20795     103975   103975
# 4  A292150        4      14450  14450      57800    57800
# 5  A114260        1      57990  57990      57990    57990
# 6  C000001  7138.75          1      1    7138.75  7138.75
#
#               itemname   asset_class       date userid  username group_by  \
# 0       KODEX 배당성장채권혼합   Alternative 2021-03-23   A008  적극투자형중규모
# 1          TIGER 소프트웨어        Equity 2021-03-23   A008  적극투자형중규모
# 2  KODEX MSCI Korea TR        Equity 2021-03-23   A008  적극투자형중규모
# 3             KODEX IT        Equity 2021-03-23   A008  적극투자형중규모
# 4          TIGER TOP10        Equity 2021-03-23   A008  적극투자형중규모
# 5          KODEX 국고채3년  Fixed Income 2021-03-23   A008  적극투자형중규모
# 6                   현금          Cash 2021-03-23   A008  적극투자형중규모
#
#   original          wt  mp_wt
# 0    Rebal    0.228217  0.240
# 1    Rebal    0.234365  0.240
# 2    Rebal    0.221819  0.240
# 3    Rebal    0.144618  0.136
# 4    Rebal   0.0803935  0.084
# 5    Rebal   0.0806578  0.060
# 6    Rebal  0.00992922  0.000

# %%
def get_rebal_comp(before, after):
    before=before.set_index('itemcode', drop=True)
    after=after.set_index('itemcode', drop=True)
    
    # 매매 전후 테이블 병합 (key: itemcode, which is already set to be the index.)
    df_comp = pd.merge(before.loc[:, ['name', 'itemname', 'quantity', 'wt', 'price', 'value']],
         after.loc[:, ['itemname', 'quantity', 'wt', 'mp_wt', 'price', 'value']],
         left_index=True,
         right_index=True,
         how='outer',
         suffixes=('_before', '_after'))
    
    # nan 셀 채우기
    df_comp.itemname_before = df_comp.itemname_before.combine_first(after.itemname)
    df_comp.itemname_after = df_comp.itemname_after.combine_first(before.itemname)
    df_comp.price_after = df_comp.price_after.combine_first(before.price)
    df_comp.name = username
    df_comp = df_comp.fillna(0)
    df_comp = df_comp.assign(quantity_diff= df_comp.quantity_after-df_comp.quantity_before)
    
    # 매수/매도 레이블링 조건 정의
    conditions = [
        df_comp.quantity_diff < 0,
        df_comp.quantity_diff == 0,
        df_comp.quantity_diff > 0
    ]
    outputs = ['매도', '-', '매수']
    
    df_comp = df_comp.assign(trade=np.select(conditions, outputs))
    df_comp = df_comp.assign(quantity_trade=np.abs(df_comp.quantity_diff.astype(int)))
    
    # 컬럼명 변경, 컬럼삭제 등 컬럼 정리
    df_comp = df_comp.drop(['itemname_after'], axis=1)
    df_comp = df_comp.sort_values(by='value_after', ascending=False)
    df_comp = df_comp.reset_index()
    
    df_comp = df_comp[['name', 'itemcode', 'itemname_before', 'quantity_before', 'wt_before', 'value_before',
                   'mp_wt', 'trade', 'quantity_trade', 'quantity_after', 'price_after', 'value_after', 'wt_after']]
    
    # 컬럼값 포멧팅(소수점 1자리, 숫자에 컴마 넣기)
    df_comp.loc[:, ['mp_wt', 'wt_before', 'wt_after']] = df_comp.loc[:, ['mp_wt', 'wt_before', 'wt_after']]*100
    df_comp.loc[:, ['wt_before', 'wt_after']] = df_comp.loc[:, ['wt_before', 'wt_after']].applymap(lambda x: '{:.1f}'.format(x))
    df_comp.loc[:, [
        'quantity_before', 'wt_before', 'value_before', 'quantity_after',
        'price_after', 'value_after'
    ]] = df_comp.loc[:, [
        'mp_wt', 'quantity_before', 'wt_before', 'value_before', 'quantity_after',
        'price_after', 'value_after'
    ]].astype(float).astype(int).applymap(lambda x: '{:,}'.format(x))

    # 컬럼명 한글로
    df_comp = df_comp.rename(columns = {
        'name':'이름',
        'itemcode':'종목코드',
        'itemname_before':'종목명',
        'quantity_before':'수량(전)',
        'wt_before':'비중(전)',
        'value_before':'평가액(전)',
        'mp_wt':'MP비중',
        'trade':'매매방향',
        'quantity_trade':'매매수량',
        'quantity_after':'수량(후)',
        'price_after':'가격(후)',
        'value_after':'평가액(후)',
        'wt_after':'비중(후)'
    })
    
    return df_comp

# %%
df_comp = get_rebal_comp(before, after)

# %%
df_comp
# Out:
#           이름     종목코드                  종목명  수량(전) 비중(전)   평가액(전)  MP비중 매매방향  \
# 0   적극투자형중규모  A157490          TIGER 소프트웨어      0     0        0  24.0   매수
# 1   적극투자형중규모  A237370       KODEX 배당성장채권혼합      0     0        0  24.0   매수
# 2   적극투자형중규모  A278540  KODEX MSCI Korea TR      0     0        0  24.0   매수
# 3   적극투자형중규모  A266370             KODEX IT      0     0        0  13.6   매수
# 4   적극투자형중규모  A114260          KODEX 국고채3년      2    17  122,052   6.0   매도
# 5   적극투자형중규모  A292150          TIGER TOP10      0     0        0   8.4   매수
# 6   적극투자형중규모  C000001                   현금  7,920     1    7,920   0.0   매도
# 7   적극투자형중규모  A069500            KODEX 200      3    17  128,810   0.0   매도
# 8   적극투자형중규모  A196230         KBSTAR 단기통안채      1    14  101,195   0.0   매도
# 9   적극투자형중규모  A302190          TIGER 중장기국채      3    22  163,378   0.0   매도
# 10  적극투자형중규모  A329750    TIGER 미국달러단기채권액티브     16    21  154,320   0.0   매도
# 11  적극투자형중규모  A360200      KINDEX 미국S&P500      4     5   41,287   0.0   매도
#
#     매매수량  수량(후)    가격(후)   평가액(후) 비중(후)
# 0     10     10   16,850  168,500  23.4
# 1     14     14   11,720  164,080  22.8
# 2     12     12   13,290  159,480  22.2
# 3      5      5   20,795  103,975  14.5
# 4      1      1   57,990   57,990   8.1
# 5      4      4   14,450   57,800   8.0
# 6    781  7,138        1    7,138   1.0
# 7      3      0   42,936        0   0.0
# 8      1      0  101,195        0   0.0
# 9      3      0   54,459        0   0.0
# 10    16      0    9,645        0   0.0
# 11     4      0   10,321        0   0.0

# %%
df_comp.to_pickle('comparison.pkl')

# %%
before.value.sum()
# Out:
# 718963.75

# %%
after
# Out:
#   itemcode quantity cost_price    price cost_value     value  \
# 0  A237370       14    11720.0  11720.0   164080.0  164080.0
# 1  A157490       10    16850.0  16850.0   168500.0  168500.0
# 2  A278540       12    13290.0  13290.0   159480.0  159480.0
# 3  A266370        5    20795.0  20795.0   103975.0  103975.0
# 4  A292150        4    14450.0  14450.0    57800.0   57800.0
# 5  A114260        1    57990.0  57990.0    57990.0   57990.0
# 6  C000001  7138.75          1        1    7138.75   7138.75
#
#               itemname   asset_class       date userid  username group_by  \
# 0       KODEX 배당성장채권혼합   Alternative 2021-03-23   A008  적극투자형중규모
# 1          TIGER 소프트웨어        Equity 2021-03-23   A008  적극투자형중규모
# 2  KODEX MSCI Korea TR        Equity 2021-03-23   A008  적극투자형중규모
# 3             KODEX IT        Equity 2021-03-23   A008  적극투자형중규모
# 4          TIGER TOP10        Equity 2021-03-23   A008  적극투자형중규모
# 5          KODEX 국고채3년  Fixed Income 2021-03-23   A008  적극투자형중규모
# 6                   현금          Cash 2021-03-23   A008  적극투자형중규모
#
#   original        wt
# 0    Rebal  0.228217
# 1    Rebal  0.234365
# 2    Rebal  0.221819
# 3    Rebal  0.144618
# 4    Rebal  0.080393
# 5    Rebal  0.080658
# 6    Rebal  0.009929

# %%
before=before.set_index('itemcode', drop=True)
after=all_the_nexts.set_index('itemcode', drop=True)

# %%
df_comp = pd.merge(before.loc[:, ['name', 'itemname', 'quantity', 'wt', 'price', 'value']],
         after.loc[:, ['itemname', 'quantity', 'wt', 'price', 'value']],
         left_index=True,
         right_index=True,
         how='outer',
         suffixes=('_before', '_after'))

# %%
df_comp.itemname_before = df_comp.itemname_before.combine_first(after.itemname)
df_comp.itemname_after = df_comp.itemname_after.combine_first(before.itemname)
df_comp.price_after = df_comp.price_after.combine_first(before.price)
df_comp.name = username
df_comp = df_comp.fillna(0)

# %%
df_comp = df_comp.assign(quantity_diff= df_comp.quantity_after-df_comp.quantity_before)

# %%
before.price
# Out:
# itemcode
# C000001         1.00
# A069500     42936.90
# A360200     10321.75
# A196230    101195.25
# A302190     54459.60
# A329750      9645.00
# A114260     61026.00
# Name: price, dtype: float64

# %%
conditions = [
    df_comp.quantity_diff < 0,
    df_comp.quantity_diff == 0,
    df_comp.quantity_diff > 0
]
outputs = ['매도', '-', '매수']

# %%
df_comp = df_comp.assign(trade=np.select(conditions, outputs))
df_comp = df_comp.assign(quantity_trade=np.abs(df_comp.quantity_diff.astype(int)))

# %%
df_comp = df_comp.drop(['itemname_after'], axis=1)
df_comp = df_comp.sort_values(by='value_after', ascending=False)
df_comp = df_comp.reset_index()

# %%
df_comp.head(1)
# Out:
#   itemcode      name itemname_before  quantity_before  wt_before  \
# 0  A237370  적극투자형중규모  KODEX 배당성장채권혼합              0.0        0.0
#
#    price_before  value_before  quantity_after  wt_after  price_after  \
# 0           0.0           0.0            29.0  0.239527      11720.0
#
#    value_after  quantity_diff trade  quantity_trade
# 0     339880.0           29.0    매수              29

# %%
df_comp.columns
# Out:
# Index(['itemcode', 'name', 'itemname_before', 'quantity_before', 'wt_before',
#        'price_before', 'value_before', 'quantity_after', 'wt_after',
#        'price_after', 'value_after', 'quantity_diff', 'trade',
#        'quantity_trade'],
#       dtype='object')

# %%
df_comp = df_comp[['name', 'itemcode', 'itemname_before', 'quantity_before', 'wt_before', 'value_before',
                   'trade', 'quantity_trade', 'quantity_after', 'price_after', 'value_after', 'wt_after']]

# %%
df_comp.loc[:, ['wt_before', 'wt_after']] = df_comp.loc[:, ['wt_before', 'wt_after']]*100
df_comp.loc[:, ['wt_before', 'wt_after']] = df_comp.loc[:, ['wt_before', 'wt_after']].applymap(lambda x: '{:.1f}'.format(x))
df_comp.loc[:, [
    'quantity_before', 'wt_before', 'value_before', 'quantity_after',
    'price_after', 'value_after'
]] = df_comp.loc[:, [
    'quantity_before', 'wt_before', 'value_before', 'quantity_after',
    'price_after', 'value_after'
]].astype(float).astype(int).applymap(lambda x: '{:,}'.format(x))

# %%
df_comp
# Out:
#         name itemcode      itemname_before quantity_before wt_before  \
# 0   적극투자형중규모  A237370       KODEX 배당성장채권혼합               0         0
# 1   적극투자형중규모  A157490          TIGER 소프트웨어               0         0
# 2   적극투자형중규모  A278540  KODEX MSCI Korea TR               0         0
# 3   적극투자형중규모  A266370             KODEX IT               0         0
# 4   적극투자형중규모  A292150          TIGER TOP10               0         0
# 5   적극투자형중규모  A114260          KODEX 국고채3년               2        17
# 6   적극투자형중규모  C000001                   현금           7,920         1
# 7   적극투자형중규모  A069500            KODEX 200               3        17
# 8   적극투자형중규모  A196230         KBSTAR 단기통안채               1        14
# 9   적극투자형중규모  A302190          TIGER 중장기국채               3        22
# 10  적극투자형중규모  A329750    TIGER 미국달러단기채권액티브              16        21
# 11  적극투자형중규모  A360200      KINDEX 미국S&P500               4         5
#
#    value_before trade  quantity_trade quantity_after price_after value_after  \
# 0             0    매수              29             29      11,720     339,880
# 1             0    매수              20             20      16,850     337,000
# 2             0    매수              25             25      13,290     332,250
# 3             0    매수               9              9      20,795     187,155
# 4             0    매수               8              8      14,450     115,600
# 5       122,052    매도               1              1      57,990      57,990
# 6         7,920    매수           41168         49,088           1      49,088
# 7       128,810    매도               3              0      42,936           0
# 8       101,195    매도               1              0     101,195           0
# 9       163,378    매도               3              0      54,459           0
# 10      154,320    매도              16              0       9,645           0
# 11       41,287    매도               4              0      10,321           0
#
#    wt_after
# 0      24.0
# 1      23.7
# 2      23.4
# 3      13.2
# 4       8.1
# 5       4.1
# 6       3.5
# 7       0.0
# 8       0.0
# 9       0.0
# 10      0.0
# 11      0.0

# %%
df_comp.total_value = '{:,}'.format(round(total_value))

# %%
df_comp.wt_after = df_comp.wt_after*100
df_comp.wt_after = df_comp.wt_after.apply(lambda x: '{:.1f}'.format(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-44b6b9f75b7a> in <module>
#       1 df_comp.wt_after=df_comp.wt_after*100
# ----> 2 df_comp.wt_after = df_comp.wt_after.apply(lambda x: '{:.1f}'.format(x))
#
# ~/anaconda3/envs/ra/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-30-44b6b9f75b7a> in <lambda>(x)
#       1 df_comp.wt_after=df_comp.wt_after*100
# ----> 2 df_comp.wt_after = df_comp.wt_after.apply(lambda x: '{:.1f}'.format(x))
#
# ValueError: Unknown format code 'f' for object of type 'str'

# %%
df_comp
# Out:
#         name itemcode      itemname_before  quantity_before  wt_before  \
# 0   적극투자형중규모  A237370       KODEX 배당성장채권혼합              0.0   0.000000
# 1   적극투자형중규모  A157490          TIGER 소프트웨어              0.0   0.000000
# 2   적극투자형중규모  A278540  KODEX MSCI Korea TR              0.0   0.000000
# 3   적극투자형중규모  A266370             KODEX IT              0.0   0.000000
# 4   적극투자형중규모  A292150          TIGER TOP10              0.0   0.000000
# 5   적극투자형중규모  A114260          KODEX 국고채3년              2.0   0.169761
# 6   적극투자형중규모  C000001                   현금           7920.0   0.011016
# 7   적극투자형중규모  A069500            KODEX 200              3.0   0.179162
# 8   적극투자형중규모  A196230         KBSTAR 단기통안채              1.0   0.140752
# 9   적극투자형중규모  A302190          TIGER 중장기국채              3.0   0.227242
# 10  적극투자형중규모  A329750    TIGER 미국달러단기채권액티브             16.0   0.214642
# 11  적극투자형중규모  A360200      KINDEX 미국S&P500              4.0   0.057426
#
#     value_before trade  quantity_trade  quantity_after  price_after  \
# 0           0.00    매수              29           29.00     11720.00
# 1           0.00    매수              20           20.00     16850.00
# 2           0.00    매수              25           25.00     13290.00
# 3           0.00    매수               9            9.00     20795.00
# 4           0.00    매수               8            8.00     14450.00
# 5      122052.00    매도               1            1.00     57990.00
# 6        7920.00    매수           41168        49088.75         1.00
# 7      128810.70    매도               3            0.00     42936.90
# 8      101195.25    매도               1            0.00    101195.25
# 9      163378.80    매도               3            0.00     54459.60
# 10     154320.00    매도              16            0.00      9645.00
# 11      41287.00    매도               4            0.00     10321.75
#
#     value_after wt_after
# 0     339880.00      0.2
# 1     337000.00      0.2
# 2     332250.00      0.2
# 3     187155.00      0.1
# 4     115600.00      0.1
# 5      57990.00      0.0
# 6      49088.75      0.0
# 7          0.00      0.0
# 8          0.00      0.0
# 9          0.00      0.0
# 10         0.00      0.0
# 11         0.00      0.0

# %%
df_comp = df_comp.rename(columns = {
    'name':'이름',
    'itemcode':'종목코드',
    'itemname_before':'종목명',
    'quantity_before':'수량(전)',
    'wt_before':'비중(전)',
    'value_before':'평가액(전)',
    'trade':'매매방향',
    'quantity_trade':'매매수량',
    'quantity_after':'수량(후)',
    'price_after':'가격(후)',
    'value_after':'평가액(후)',
    'wt_after':'비중(후)'
})

# %%
# df_comp.columns = pd.MultiIndex.from_arrays([['', '', '리밸런싱 전', '리밸런싱 전', '리밸런싱 전',
#                             '리밸런싱 전', '리밸런싱 방법', '리밸런싱 방법', '리밸런싱 후', '리밸런싱 후',
#                             '리밸런싱 후', '리밸런싱 후'], df_comp.columns])

# %%
df_comp
# Out:
#                                     리밸런싱 전                               \
#           이름     종목코드                  종목명      수량        비중        평가액
# 0   적극투자형중규모  A237370       KODEX 배당성장채권혼합     0.0  0.000000       0.00
# 1   적극투자형중규모  A157490          TIGER 소프트웨어     0.0  0.000000       0.00
# 2   적극투자형중규모  A278540  KODEX MSCI Korea TR     0.0  0.000000       0.00
# 3   적극투자형중규모  A266370             KODEX IT     0.0  0.000000       0.00
# 4   적극투자형중규모  A292150          TIGER TOP10     0.0  0.000000       0.00
# 5   적극투자형중규모  A114260          KODEX 국고채3년     2.0  0.169761  122052.00
# 6   적극투자형중규모  C000001                   현금  7920.0  0.011016    7920.00
# 7   적극투자형중규모  A069500            KODEX 200     3.0  0.179162  128810.70
# 8   적극투자형중규모  A196230         KBSTAR 단기통안채     1.0  0.140752  101195.25
# 9   적극투자형중규모  A302190          TIGER 중장기국채     3.0  0.227242  163378.80
# 10  적극투자형중규모  A329750    TIGER 미국달러단기채권액티브    16.0  0.214642  154320.00
# 11  적극투자형중규모  A360200      KINDEX 미국S&P500     4.0  0.057426   41287.00
#
#    리밸런싱 방법           리밸런싱 후
#       매매방향   매매수량        수량         가격        평가액        비중
# 0       매수     29     29.00   11720.00  339880.00  0.239527
# 1       매수     20     20.00   16850.00  337000.00  0.237497
# 2       매수     25     25.00   13290.00  332250.00  0.234150
# 3       매수      9      9.00   20795.00  187155.00  0.131896
# 4       매수      8      8.00   14450.00  115600.00  0.081468
# 5       매도      1      1.00   57990.00   57990.00  0.040868
# 6       매수  41168  49088.75       1.00   49088.75  0.034595
# 7       매도      3      0.00   42936.90       0.00  0.000000
# 8       매도      1      0.00  101195.25       0.00  0.000000
# 9       매도      3      0.00   54459.60       0.00  0.000000
# 10      매도     16      0.00    9645.00       0.00  0.000000
# 11      매도      4      0.00   10321.75       0.00  0.000000

# %%
advised_pf
# Out:
#              date  risk_profile itemcode   weights tracking_code  \
# 0      2019-01-02             2  A273130  0.240000   ACT_BOND_D4
# 1      2019-01-02             2  A214980  0.240000       MM_PLUS
# 2      2019-01-02             2  A196230  0.207716       BOK_D.4
# 3      2019-01-02             2  A114260  0.100000        KTB_D3
# 4      2019-01-02             2  A122260  0.092284        BOK_D1
# ...           ...           ...      ...       ...           ...
# 19383  2021-04-30             4  A237370  0.240000   BAL_KO3KTB7
# 19384  2021-04-30             4  A278540  0.240000       MSCI_KR
# 19385  2021-04-30             4  A266370  0.136000            IT
# 19386  2021-04-30             4  A292150  0.084000         TOP10
# 19387  2021-04-30             4  A114260  0.060000        KTB_D3
#
#                    itemname     price    volume  trading_amt_mln   asset_class
# 0      KODEX 종합채권(AA-이상)액티브  104320.0   26468.0       858.104496  Fixed Income
# 1            KODEX 단기채권PLUS  100050.0   10160.0       508.874866  Fixed Income
# 2              KBSTAR 단기통안채  101423.0  393085.0     16568.430895  Fixed Income
# 3               KODEX 국고채3년   55690.0    5449.0       251.127486  Fixed Income
# 4               KOSEF 통안채1년   97761.0   42453.0     13238.397304  Fixed Income
# ...                     ...       ...       ...              ...           ...
# 19383        KODEX 배당성장채권혼합   12060.0    5299.0       123.076578   Alternative
# 19384   KODEX MSCI Korea TR   13695.0  471792.0     14353.562789        Equity
# 19385              KODEX IT   20760.0   21069.0      1087.656470        Equity
# 19386           TIGER TOP10   14305.0  547411.0     14890.029898        Equity
# 19387           KODEX 국고채3년   58040.0    5351.0       938.070000  Fixed Income
#
# [19388 rows x 10 columns]

# %%
current_date = '2021-1-4'
current_date = datetime.strptime(current_date, '%Y-%m-%d').strftime('%Y-%m-%d')

# %%
current_date
# Out:
# '2021-01-04'

# %%
df = advised_pf.loc[(advised_pf.date==current_date) & (advised_pf.risk_profile==int('4')), :]

# %%
df.tail(30)
# Out:
#             date  risk_profile itemcode  weights tracking_code       itemname  \
# 1831  2021-01-04             4  A157490     0.25            SW    TIGER 소프트웨어
# 1832  2021-01-04             4  A139260     0.25       K200_IT   TIGER 200 IT
# 1833  2021-01-04             4  A266370     0.25            IT       KODEX IT
# 1834  2021-01-04             4  A091160     0.20      SEMI_KRX      KODEX 반도체
# 1835  2021-01-04             4  A229200     0.05         KQ150  KODEX 코스닥 150
#
#         price     volume  trading_amt_mln asset_class
# 1831  14935.0   227434.0      1868.593400      Equity
# 1832  37650.0  1550986.0     11192.305263      Equity
# 1833  20805.0   152199.0       539.058393      Equity
# 1834  34355.0   425277.0      2607.676698      Equity
# 1835  15400.0  5770313.0    119331.906733      Equity

# %%
df.tail(20)
# Out:
#             date  risk_profile itemcode  weights tracking_code       itemname  \
# 1820  2021-01-04             2  A122260     0.25        BOK_D1    KOSEF 통안채1년
# 1821  2021-01-04             2  A114260     0.25        KTB_D3    KODEX 국고채3년
# 1822  2021-01-04             2  A130730     0.25            MM     KOSEF 단기자금
# 1823  2021-01-04             2  A329650     0.15   BAL_WO3KTB7  KODEX TRF3070
# 1824  2021-01-04             2  A266370     0.10            IT       KODEX IT
#
#          price    volume  trading_amt_mln   asset_class
# 1820  101015.0    2773.0     53191.510933  Fixed Income
# 1821   58100.0    4571.0       547.479291  Fixed Income
# 1822  100835.0   88085.0     59165.272681  Fixed Income
# 1823   10735.0   33117.0       122.211411   Alternative
# 1824   20805.0  152199.0       539.058393        Equity

# %%
s = '투자자9'

# %%
import re

# %%
'A' + ('0'+re.findall('\d+', s )[0])[-2:]
# Out:
# 'A09'

# %%
balance_s.columns
# Out:
# Index(['date', 'userid', 'name', 'asset_class', 'itemcode', 'itemname',
#        'quantity', 'cost_price', 'cost_value', 'price', 'value', 'wt',
#        'group_by', 'principal'],
#       dtype='object')

# %%
balance = [
    ('3/22/2021 7:50:25 PM', 'A50', '투자자50', '현금성', 'C000001', '현금', 1000000.0,
     1.0, 1000000.0, 1.0, 1000000.0, 1.0, '2021322:50현금성', 'Y'),
    ('3/22/2021 7:50:25 PM', 'A50', '투자자50', '현금성', 'C000001', '현금', 1000000.0,
     1.0, 1000000.0, 1.0, 1000000.0, 1.0, '2021322:50현금성', 'Y')
]

# %%
balance = pd.DataFrame(balance, columns=['date', 'userid', 'name', 'asset_class', 'itemcode', 'itemname',
       'quantity', 'cost_price', 'cost_value', 'price', 'value', 'wt',
       'group_by', 'original'])

# %%
balance.drop(['price'], axis=1)
# Out:
#                    date userid   name asset_class itemcode itemname  \
# 0  3/22/2021 7:50:25 PM    A50  투자자50         현금성  C000001       현금
# 1  3/22/2021 7:50:25 PM    A50  투자자50         현금성  C000001       현금
#
#     quantity  cost_price  cost_value      value   wt       group_by original
# 0  1000000.0         1.0   1000000.0  1000000.0  1.0  2021322:50현금성        Y
# 1  1000000.0         1.0   1000000.0  1000000.0  1.0  2021322:50현금성        Y

# %%
import plotly.express as px

# %%
pie = px.pie(df, names=df.iloc[:,0], values=df.iloc[:,1])

# %%
df
# Out:
#              종목명    비중
# 0       KODEX IT  0.10
# 1  KODEX TRF3070  0.15
# 2    KODEX 국고채3년  0.25
# 3     KOSEF 단기자금  0.25
# 4    KOSEF 통안채1년  0.25

# %%
pie.show()
# Out:
# <div>                            <div id="fd245cdf-4789-4df0-8220-37fdc9748250" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd245cdf-4789-4df0-8220-37fdc9748250")) {                    Plotly.newPlot(                        "fd245cdf-4789-4df0-8220-37fdc9748250",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "label=%{label}<br>value=%{value}<extra></extra>", "labels": ["KODEX IT", "KODEX TRF3070", "KODEX \uad6d\uace0\ucc443\ub144", "KOSEF \ub2e8\uae30\uc790\uae08", "KOSEF \ud1b5\uc548\ucc441\ub144"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [0.09999999999984686, 0.15000000000010436, 0.24999999999972888, 0.24999999999972633, 0.24999999999972916]}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords" ...

# %%
df
# Out:
#              종목명    비중
# 0       KODEX IT  0.10
# 1  KODEX TRF3070  0.15
# 2    KODEX 국고채3년  0.25
# 3     KOSEF 단기자금  0.25
# 4    KOSEF 통안채1년  0.25

# %%
df
# Out:
#             date  risk_profile itemcode  weights tracking_code       itemname  \
# 2453  2021-02-26             2  A122260     0.25        BOK_D1    KOSEF 통안채1년
# 2454  2021-02-26             2  A114260     0.25        KTB_D3    KODEX 국고채3년
# 2455  2021-02-26             2  A130730     0.25            MM     KOSEF 단기자금
# 2456  2021-02-26             2  A329650     0.15   BAL_WO3KTB7  KODEX TRF3070
# 2457  2021-02-26             2  A266370     0.10            IT       KODEX IT
#
#          price    volume  trading_amt_mln   asset_class
# 2453  101155.0  829489.0     61672.391133  Fixed Income
# 2454   58090.0    5062.0       821.950469  Fixed Income
# 2455  100960.0  965560.0     64369.329522  Fixed Income
# 2456   10925.0   28428.0       210.266644   Alternative
# 2457   21480.0  118417.0      1091.216569        Equity

# %%
        df.loc[:, ['weights', 'itemname']].groupby(
            'itemname').sum().reset_index().rename(columns={
                'itemcode': '종목명',
                'weights': '비중'
            })
# Out:
#         itemname    비중
# 0       KODEX IT  0.10
# 1  KODEX TRF3070  0.15
# 2    KODEX 국고채3년  0.25
# 3     KOSEF 단기자금  0.25
# 4    KOSEF 통안채1년  0.25

# %%
print(advised_pf.columns)
# Out:
# Index(['date', 'risk_profile', 'itemcode', 'weights', 'tracking_code',
#        'itemname', 'price', 'volume', 'trading_amt_mln', 'asset_class'],
#       dtype='object')

# %%
current_date='2020-2-1'

# %%
advised_pf.date
# Out:
# 0      2020-02-03
# 1      2020-02-03
# 2      2020-02-03
# 3      2020-02-03
# 4      2020-02-03
#           ...
# 456    2020-02-28
# 457    2020-02-28
# 458    2020-02-28
# 459    2020-02-28
# 460    2020-02-28
# Name: date, Length: 461, dtype: object

# %%
for index, row in advised_pf.iterrows():
    print(row.date, row.risk_profile)
# Out:
# 2020-08-03 2
# 2020-08-03 2
# 2020-08-03 2
# 2020-08-03 2
# 2020-08-03 2
# 2020-08-03 3
# 2020-08-03 3
# 2020-08-03 3
# 2020-08-03 3
# 2020-08-03 3
# 2020-08-03 3
# 2020-08-03 4
# 2020-08-03 4
# 2020-08-03 4
# 2020-08-03 4
# 2020-08-03 4
# 2020-08-04 2
# 2020-08-04 2
# 2020-08-04 2
# 2020-08-04 2
# 2020-08-04 2
# 2020-08-04 3
# 2020-08-04 3
# 2020-08-04 3
# 2020-08-04 3
# 2020-08-04 3
# 2020-08-04 3
# 2020-08-04 4
# 2020-08-04 4
# 2020-08-04 4
# 2020-08-04 4
# 2020-08-04 4
# 2020-08-04 4
# 2020-08-05 2
# 2020-08-05 2
# 2020-08-05 2
# 2020-08-05 2
# 2020-08-05 2
# 2020-08-05 3
# 2020-08-05 3
# 2020-08-05 3
# 2020-08-05 3
# 2020-08-05 3
# 2020-08-05 3
# 2020-08-05 4
# 2020-08-05 4
# 2020-08-05 4
# 2020-08-05 4
# 2020-08-05 4
# 2020-08-05 4
# 2020-08-06 2
# 2020-08-06 2
# 2020-08-06 2
# 2020-08-06 2
# 2020-08-06 2
# 2020-08-06 3
# 2020-08-06 3
# 2020-08-06 3
# 2020-08-06 3
# 2020-08-06 3
# 2020-08-06 3
# 2021-02-23 4
# 2021-02-23 4
# 2021-02-23 4
# 2021-02-23 4
# 2021-02-24 2
# 2021-02-24 2
# 2021-02-24 2
# 2021-02-24 2
# 2021-02-24 2
# 2021-02-24 3
# 2021-02-24 3
# 2021-02-24 3
# 2021-02-24 3
# 2021-02-24 3
# 2021-02-24 3
# 2021-02-24 4
# 2021-02-24 4
# 2021-02-24 4
# 2021-02-24 4
# 2021-02-24 4
# 2021-02-25 2
# 2021-02-25 2
# 2021-02-25 2
# 2021-02-25 2
# 2021-02-25 2
# 2021-02-25 3
# 2021-02-25 3
# 2021-02-25 3
# 2021-02-25 3
# 2021-02-25 3
# 2021-02-25 3
# 2021-02-25 4
# 2021-02-25 4
# 2021-02-25 4
# 2021-02-25 4
# 2021-02-25 4
# 2021-02-26 2
# 2021-02-26 2
# 2021-02-26 2
# 2021-02-26 2
# 2021-02-26 2
# 2021-02-26 3
# 2021-02-26 3
# 2021-02-26 3
# 2021-02-26 3
# 2021-02-26 3
# 2021-02-26 3
# 2021-02-26 4
# 2021-02-26 4
# 2021-02-26 4
# 2021-02-26 4
# 2021-02-26 4

# %%
pd.read_pickle('./data/processed/universe.pkl')
# Out:
#    itemcode           itemname   price       nav  volumne_sh  trading_amt_mln  \
# 0   C000001                 현금       1       1.0         NaN              NaN
# 1   D000001                 예금       1       1.0         NaN              NaN
# 2   A069500          KODEX 200   42095   42105.0   5426223.0         228445.0
# 3   A277630          TIGER 코스피   31060   31050.0      4776.0            148.0
# 4   A292160       TIGER KRX300   19250   19270.0     60658.0           1163.0
# ..      ...                ...     ...       ...         ...              ...
# 94  A130730         KOSEF 단기자금  100970  100968.0    211753.0          21380.0
# 95  A122260        KOSEF 통안채1년  101170  101173.0    193096.0          19536.0
# 96  A329750  TIGER 미국달러단기채권액티브    9645       NaN     78822.0            760.0
# 97  A196230       KBSTAR 단기통안채  104325  104325.0    388477.0          40527.0
# 98  A329650      KODEX TRF3070   10980       NaN     37484.0            411.0
#
#     market_cap_100m exchange_nm    market   asset_class instruments  exposure  \
# 0               NaN         NaN  Domestic          Cash        Cash      Cash
# 1               NaN         NaN  Domestic          Cash     Deposit   Deposit
# 2          51545.00         KRX  Domestic        Equity         ETF     Large
# 3            637.00         KRX  Domestic        Equity         ETF     Broad
# 4            327.00         KRX  Domestic        Equity         ETF     Large
# ..              ...         ...       ...           ...         ...       ...
# 94           486.00         KRX  Domestic  Fixed Income         ETF     Money
# 95           475.00         KRX  Domestic  Fixed Income         ETF    ShortD
# 96           378.00         KRX       USA   Alternative         ETF     Money
# 97          1847.00         KRX  Domestic  Fixed Income         ETF     Money
# 98           239.21         KRX  Domestic   Alternative         ETF  Balanced
#
#     dc_risky_asset
# 0              1.0
# 1              1.0
# 2              0.7
# 3              0.7
# 4              0.7
# ..             ...
# 94             1.0
# 95             1.0
# 96             1.0
# 97             1.0
# 98             1.0
#
# [99 rows x 13 columns]

# %%
['a','b'] + ['c']
# Out:
# ['a', 'b', 'c']

# %%
def get_advised_portfolios
