# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %% [markdown]
# ### Internal DB
# - Data of users, profiles, balance, instruments, trades and universe.

# %% [markdown]
# #### Load plain data files store them into pickle formats.

# %%
data_files = ['profiles_m']
filepath = '../../data/processed/'
df = {}
for filename in data_files:
    df[filename] = pd.read_csv(filepath + filename + '.dat', header=1)

# %%
df['profiles_m'][df['profiles_m'].q_no>=5]
# Out:
#     Unnamed: 0  set_no  q_no          question              choices  \
# 18          18       1     5  다른 주식형(고위험) 상품비중           순자산의 5% 이하
# 19          19       1     5  다른 주식형(고위험) 상품비중               10% 이하
# 20          20       1     5  다른 주식형(고위험) 상품비중               20% 이하
# 21          21       1     5  다른 주식형(고위험) 상품비중               30% 이하
# 22          22       1     5  다른 주식형(고위험) 상품비중               30% 초과
# 23          23       1     6              투자기간                1년 이하
# 24          24       1     6              투자기간                3년 이하
# 25          25       1     6              투자기간                5년 이하
# 26          26       1     6              투자기간                5년 초과
# 27          27       1     7               연령대               10대 미만
# 28          28       1     7               연령대                  10대
# 29          29       1     7               연령대                  20대
# 30          30       1     7               연령대                  30대
# 31          31       1     7               연령대                  40대
# 32          32       1     7               연령대                  50대
# 33          33       1     7               연령대               60대 이상
# 34          34       1     8              자기평가  원금손실 가능한 투자상품 경험 없음
# 35          35       1     8              자기평가  혼합형 펀드나 ELS 투자경험 있음
# 36          36       1     8              자기평가  주식형 펀드나 ETF 투자경험 있음
# 37          37       1     8              자기평가           주식 투자경험 있음
#
#     risk_pref_value         choice-id
# 18                1        lower-five
# 19                2         lower-ten
# 20                3      lower-twenty
# 21                4      lower-thirty
# 22                5       over-thirty
# 23                2    below-one-year
# 24                3  below-three-year
# 25                4   below-five-year
# 26                5    over-five-year
# 27                3     below-teenage
# 28                4           teenage
# 29                5           two-age
# 30                4         three-age
# 31                3          four-age
# 32                2          five-age
# 33                1           six-age
# 34                1         no-invest
# 35                3               ELS
# 36                4              fund
# 37                5             stock

# %%
data_files = ['investors_m', 'profiles_m', 'profiles_s', 'balance_m', 'balance_s', 'instruments_m', 'trades', 'universe', 'constraints']
filepath = '../../data/processed/'
df = {}
for filename in data_files:
    df[filename] = pd.read_csv(filepath + filename + '.dat', header=1)
    df[filename].to_pickle(filepath + filename + '.pkl')

# %%
for filename in data_files:
    display(df[filename].head())
# Out:
#   userid  name account_nm  profile_code
# 0    A01  투자자1    acc1-01             2
# 1    A01  투자자1    acc1-02             2
# 2    A02  투자자2    acc2-01             2
# 3    A03  투자자3    acc3-01             3
# 4    A04  투자자4    acc4-01             4
#    set_no  q_no question choices  risk_pref_value
# 0       1     1     투자경험      없음                1
# 1       1     1     투자경험  6개월 이하                2
# 2       1     1     투자경험   1년 이하                3
# 3       1     1     투자경험   2년 이하                4
# 4       1     1     투자경험   2년 초과                5
#   userid  set_no  q_no  answer  risk_pref_value
# 0    A01       1     1       2                2
# 1    A01       1     2       2                2
# 2    A01       1     3       3                3
# 3    A01       1     4       3                3
# 4    A01       1     5       1                4
#                    date userid asset_class     value        wt
# 0  1/10/2020 1:00:00 PM    A01         현금성  700000.0  1.000000
# 1  1/10/2020 4:00:00 PM    A01         현금성  364555.0  0.518938
# 2  1/10/2020 4:00:00 PM    A01          주식   85527.7  0.121747
# 3  1/10/2020 4:00:00 PM    A01          채권  215383.1  0.306594
# 4  1/10/2020 4:00:00 PM    A01          대체   37036.8  0.052721
#                    date userid  name asset_class itemcode         itemname  \
# 0  1/10/2020 1:00:00 PM    A01  투자자1         현금성  C000001               현금
# 1  1/10/2020 4:00:00 PM    A01  투자자1         현금성  C000001               현금
# 2  1/10/2020 4:00:00 PM    A01  투자자1         현금성  D000001               예금
# 3  1/10/2020 4:00:00 PM    A01  투자자1          주식  A069500        KODEX 200
# 4  1/10/2020 4:00:00 PM    A01  투자자1          주식  A360200  KINDEX 미국S&P500
#
#    quantity  cost_price  cost_value     price     value        wt  \
# 0    700000           1      700000      1.00  700000.0  1.000000
# 1     11055           1       11055      1.00   11055.0  0.015737
# 2    350000           1      350000      1.01  353500.0  0.503201
# 3         1       42095       42095  42936.90   42936.9  0.061120
# 4         4       10865       43460  10647.70   42590.8  0.060627
#
#             group_by 투자원본
# 0  20200110 13:00현금성    Y
# 1  20200110 16:00현금성    N
# 2  20200110 16:00현금성    N
# 3   20200110 16:00주식    N
# 4   20200110 16:00주식    N
#   itemcode    itemname tracking_code  tracking_ticker  tracking_nm  \
# 0  C000001          현금          CASH              NaN          NaN
# 1  D000001          예금       DEPOSIT              NaN          NaN
# 2  A069500   KODEX 200          K200              NaN          NaN
# 3  A105190  KINDEX 200          K200              NaN          NaN
# 4  A102110   TIGER 200          K200              NaN          NaN
#
#    inception_dt    market asset_class instruments exposure dc_risky_asset  \
# 0           NaN  Domestic        Cash        Cash     Cash              N
# 1           NaN  Domestic        Cash     Deposit  Deposit              N
# 2           NaN  Domestic      Equity         ETF    Large              Y
# 3           NaN  Domestic      Equity         ETF    Large              Y
# 4           NaN  Domestic      Equity         ETF    Large              Y
#
#   strategy  issuer
# 0      NaN     KIS
# 1      NaN     KIS
# 2     Core   KODEX
# 3     Core  KINDEX
# 4     Core   TIGER
#            trade_no                  date userid BS itemcode         itemname  \
# 0  A01-20200110-001  1/10/2020 2:00:00 PM    A01  S  C000001               현금
# 1  A01-20200110-002  1/10/2020 2:00:00 PM    A01  B  D000001               예금
# 2  A01-20200110-003  1/10/2020 2:00:00 PM    A01  B  A069500        KODEX 200
# 3  A01-20200110-004  1/10/2020 2:00:00 PM    A01  B  A360200  KINDEX 미국S&P500
# 4  A01-20200110-004  1/10/2020 2:00:00 PM    A01  B  A196230     KBSTAR 단기통안채
#
#    quantity   price   value  fee  tax
# 0    688945       1  688945    0    0
# 1    350000       1  350000    0    0
# 2         1   42095   42095    0    0
# 3         4   10865   43460    0    0
# 4         1  104325  104325    0    0
#   itemcode      itemname  price      nav  volumne_sh  trading_amt_mln  \
# 0  C000001            현금      1      1.0         NaN              NaN
# 1  D000001            예금      1      1.0         NaN              NaN
# 2  A069500     KODEX 200  42095  42105.0   5426223.0         228445.0
# 3  A277630     TIGER 코스피  31060  31050.0      4776.0            148.0
# 4  A292160  TIGER KRX300  19250  19270.0     60658.0           1163.0
#
#    market_cap_100m exchange_nm    market asset_class instruments exposure  \
# 0              NaN         NaN  Domestic        Cash        Cash     Cash
# 1              NaN         NaN  Domestic        Cash     Deposit  Deposit
# 2          51545.0         KRX  Domestic      Equity         ETF    Large
# 3            637.0         KRX  Domestic      Equity         ETF    Broad
# 4            327.0         KRX  Domestic      Equity         ETF    Large
#
#    dc_risky_asset
# 0             1.0
# 1             1.0
# 2             0.7
# 3             0.7
# 4             0.7
#    2  FALSE  Classes  Asset class       Equity  >=  0.03 Unnamed: 7  \
# 0  2  False  Classes  Asset class       Equity  <=  0.10        NaN
# 1  2  False   Assets          NaN      A130730  >=  0.20        NaN
# 2  2  False   Assets          NaN      A153130  >=  0.20        NaN
# 3  2  False   Assets          NaN      A214980  >=  0.10        NaN
# 4  2  False  Classes  Asset class  Alternative  <=  0.05        NaN
#
#   Unnamed: 8 Unnamed: 9  Unnamed: 10
# 0        NaN        NaN          NaN
# 1        NaN        NaN          NaN
# 2        NaN        NaN          NaN
# 3        NaN        NaN          NaN
# 4        NaN        NaN          NaN
