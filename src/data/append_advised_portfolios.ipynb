# %%
import pandas as pd

# %%
access_path = '../../data/processed/'
filename = ['advised_portfolios.pkl', 'advised_portfolios-0601.pkl']
full_path = [access_path + file_nm for file_nm in filename]

# %%
ports = [pd.read_pickle(file) for file in full_path]

# %%
ports[0]
# Out:
#              date  risk_profile itemcode   weights tracking_code  \
# 0      2019-01-02             2  A273130  0.240000   ACT_BOND_D4
# 1      2019-01-02             2  A214980  0.240000       MM_PLUS
# 2      2019-01-02             2  A196230  0.207716       BOK_D.4
# 3      2019-01-02             2  A114260  0.100000        KTB_D3
# 4      2019-01-02             2  A122260  0.092284        BOK_D1
# ...           ...           ...      ...       ...           ...
# 19509  2021-05-06             4  A278540  0.240000       MSCI_KR
# 19510  2021-05-06             4  A157490  0.240000            SW
# 19511  2021-05-06             4  A266370  0.136000            IT
# 19512  2021-05-06             4  A069500  0.084000          K200
# 19513  2021-05-06             4  A114260  0.060000        KTB_D3
#
#                    itemname     price     volume  trading_amt_mln  \
# 0      KODEX 종합채권(AA-이상)액티브  104320.0    26468.0       858.104496
# 1            KODEX 단기채권PLUS  100050.0    10160.0       508.874866
# 2              KBSTAR 단기통안채  101423.0   393085.0     16568.430895
# 3               KODEX 국고채3년   55690.0     5449.0       251.127486
# 4               KOSEF 통안채1년   97761.0    42453.0     13238.397304
# ...                     ...       ...        ...              ...
# 19509   KODEX MSCI Korea TR   13810.0   401336.0     14336.127555
# 19510           TIGER 소프트웨어   16670.0   104451.0      2637.322487
# 19511              KODEX IT   20525.0    14105.0      1070.447295
# 19512             KODEX 200   42630.0  4079571.0    368064.948968
# 19513           KODEX 국고채3년   58060.0     2238.0       943.544023
#
#         asset_class
# 0      Fixed Income
# 1      Fixed Income
# 2      Fixed Income
# 3      Fixed Income
# 4      Fixed Income
# ...             ...
# 19509        Equity
# 19510        Equity
# 19511        Equity
# 19512        Equity
# 19513  Fixed Income
#
# [19514 rows x 10 columns]

# %%
ports[1]
# Out:
#            date  risk_profile itemcode   weights tracking_code  \
# 0    2021-05-07             2  A114260  0.240000        KTB_D3
# 1    2021-05-07             2  A122260  0.240000        BOK_D1
# 2    2021-05-07             2  A130730  0.240000            MM
# 3    2021-05-07             2  A196230  0.083929       BOK_D.4
# 4    2021-05-07             2  A273130  0.076071   ACT_BOND_D4
# ..          ...           ...      ...       ...           ...
# 541  2021-06-01             4  A157490  0.240000            SW
# 542  2021-06-01             4  A278540  0.240000       MSCI_KR
# 543  2021-06-01             4  A266370  0.136000            IT
# 544  2021-06-01             4  A069500  0.084000          K200
# 545  2021-06-01             4  A114260  0.060000        KTB_D3
#
#                  itemname     price     volume  trading_amt_mln   asset_class
# 0             KODEX 국고채3년   58055.0    11739.0       935.482379  Fixed Income
# 1             KOSEF 통안채1년  101330.0   658165.0     37510.592314  Fixed Income
# 2              KOSEF 단기자금  101100.0   176641.0     68231.636524  Fixed Income
# 3            KBSTAR 단기통안채  104445.0   936288.0     53069.439176  Fixed Income
# 4    KODEX 종합채권(AA-이상)액티브  108590.0    22802.0      1945.100057  Fixed Income
# ..                    ...       ...        ...              ...           ...
# 541           TIGER 소프트웨어   17690.0   148623.0      2490.713941        Equity
# 542   KODEX MSCI Korea TR   13735.0   280278.0      9454.867980        Equity
# 543              KODEX IT   20325.0    10876.0       799.389367        Equity
# 544             KODEX 200   43005.0  3845391.0    314656.633188        Equity
# 545           KODEX 국고채3년   57990.0     2678.0       790.152822  Fixed Income
#
# [546 rows x 10 columns]

# %%
df = pd.concat(ports, axis=0)
df = df.reset_index(drop=True)

# %%
df
# Out:
#              date  risk_profile itemcode   weights tracking_code  \
# 0      2019-01-02             2  A273130  0.240000   ACT_BOND_D4
# 1      2019-01-02             2  A214980  0.240000       MM_PLUS
# 2      2019-01-02             2  A196230  0.207716       BOK_D.4
# 3      2019-01-02             2  A114260  0.100000        KTB_D3
# 4      2019-01-02             2  A122260  0.092284        BOK_D1
# ...           ...           ...      ...       ...           ...
# 20055  2021-06-01             4  A157490  0.240000            SW
# 20056  2021-06-01             4  A278540  0.240000       MSCI_KR
# 20057  2021-06-01             4  A266370  0.136000            IT
# 20058  2021-06-01             4  A069500  0.084000          K200
# 20059  2021-06-01             4  A114260  0.060000        KTB_D3
#
#                    itemname     price     volume  trading_amt_mln  \
# 0      KODEX 종합채권(AA-이상)액티브  104320.0    26468.0       858.104496
# 1            KODEX 단기채권PLUS  100050.0    10160.0       508.874866
# 2              KBSTAR 단기통안채  101423.0   393085.0     16568.430895
# 3               KODEX 국고채3년   55690.0     5449.0       251.127486
# 4               KOSEF 통안채1년   97761.0    42453.0     13238.397304
# ...                     ...       ...        ...              ...
# 20055           TIGER 소프트웨어   17690.0   148623.0      2490.713941
# 20056   KODEX MSCI Korea TR   13735.0   280278.0      9454.867980
# 20057              KODEX IT   20325.0    10876.0       799.389367
# 20058             KODEX 200   43005.0  3845391.0    314656.633188
# 20059           KODEX 국고채3년   57990.0     2678.0       790.152822
#
#         asset_class
# 0      Fixed Income
# 1      Fixed Income
# 2      Fixed Income
# 3      Fixed Income
# 4      Fixed Income
# ...             ...
# 20055        Equity
# 20056        Equity
# 20057        Equity
# 20058        Equity
# 20059  Fixed Income
#
# [20060 rows x 10 columns]

# %%
df.to_pickle(access_path + 'advised_portfolios.pkl')

# %%
import datetime
# BDay is business day, not birthday...
from pandas.tseries.offsets import BDay

today = datetime.datetime.today()
print(today - BDay(1))
# Out:
# 2021-05-31 18:35:34.740596

# %%
df[df.date=='2021-06-01']
# Out:
#              date  risk_profile itemcode   weights tracking_code  \
# 20039  2021-06-01             2  A114260  0.240000        KTB_D3
# 20040  2021-06-01             2  A122260  0.240000        BOK_D1
# 20041  2021-06-01             2  A130730  0.240000            MM
# 20042  2021-06-01             2  A196230  0.086007       BOK_D.4
# 20043  2021-06-01             2  A273130  0.073993   ACT_BOND_D4
# 20044  2021-06-01             2  A069500  0.060203          K200
# 20045  2021-06-01             2  A251350  0.039797       MSCI_WO
# 20046  2021-06-01             2  A237370  0.020000   BAL_KO3KTB7
# 20047  2021-06-01             3  A114260  0.240000        KTB_D3
# 20048  2021-06-01             3  A148070  0.240000        KTB_D8
# 20049  2021-06-01             3  A069500  0.187284          K200
# 20050  2021-06-01             3  A251350  0.128716       MSCI_WO
# 20051  2021-06-01             3  A273130  0.100000   ACT_BOND_D4
# 20052  2021-06-01             3  A157490  0.084000            SW
# 20053  2021-06-01             3  A237370  0.020000   BAL_KO3KTB7
# 20054  2021-06-01             4  A237370  0.240000   BAL_KO3KTB7
# 20055  2021-06-01             4  A157490  0.240000            SW
# 20056  2021-06-01             4  A278540  0.240000       MSCI_KR
# 20057  2021-06-01             4  A266370  0.136000            IT
# 20058  2021-06-01             4  A069500  0.084000          K200
# 20059  2021-06-01             4  A114260  0.060000        KTB_D3
#
#                    itemname     price     volume  trading_amt_mln  \
# 20039           KODEX 국고채3년   57990.0     2678.0       790.152822
# 20040           KOSEF 통안채1년  101305.0    14397.0     40897.488193
# 20041            KOSEF 단기자금  101150.0   610525.0     72761.261274
# 20042          KBSTAR 단기통안채  104470.0   779089.0     50249.781876
# 20043  KODEX 종합채권(AA-이상)액티브  108305.0     8937.0      2026.077172
# 20044             KODEX 200   43005.0  3845391.0    314656.633188
# 20045   KODEX 선진국MSCI World   18610.0    60234.0      2861.718129
# 20046        KODEX 배당성장채권혼합   12090.0     4448.0       110.275609
# 20047           KODEX 국고채3년   57990.0     2678.0       790.152822
# 20048          KOSEF 국고채10년  119330.0     6533.0      1810.225724
# 20049             KODEX 200   43005.0  3845391.0    314656.633188
# 20050   KODEX 선진국MSCI World   18610.0    60234.0      2861.718129
# 20051  KODEX 종합채권(AA-이상)액티브  108305.0     8937.0      2026.077172
# 20052           TIGER 소프트웨어   17690.0   148623.0      2490.713941
# 20053        KODEX 배당성장채권혼합   12090.0     4448.0       110.275609
# 20054        KODEX 배당성장채권혼합   12090.0     4448.0       110.275609
# 20055           TIGER 소프트웨어   17690.0   148623.0      2490.713941
# 20056   KODEX MSCI Korea TR   13735.0   280278.0      9454.867980
# 20057              KODEX IT   20325.0    10876.0       799.389367
# 20058             KODEX 200   43005.0  3845391.0    314656.633188
# 20059           KODEX 국고채3년   57990.0     2678.0       790.152822
#
#         asset_class
# 20039  Fixed Income
# 20040  Fixed Income
# 20041  Fixed Income
# 20042  Fixed Income
# 20043  Fixed Income
# 20044        Equity
# 20045        Equity
# 20046   Alternative
# 20047  Fixed Income
# 20048  Fixed Income
# 20049        Equity
# 20050        Equity
# 20051  Fixed Income
# 20052        Equity
# 20053   Alternative
# 20054   Alternative
# 20055        Equity
# 20056        Equity
# 20057        Equity
# 20058        Equity
# 20059  Fixed Income
