# %%
import pandas as pd
from datetime import datetime

# %%
csv_file0601 = '../../data/processed/advised_portfolios-0601.dat'
df = pd.read_csv(csv_file0601, parse_dates=['date'])

# %%
df.date = df.date.dt.strftime('%Y-%m-%d')

# %%
df.to_pickle('../../data/processed/advised_portfolios-0601_new.pkl')

# %%
access_path = '../../data/processed/'
filename = ['advised_portfolios-start-to-20210506.pkl', 'advised_portfolios-0601_new.pkl']
full_path = [access_path + file_nm for file_nm in filename]

# %%
ports = [pd.read_pickle(file) for file in full_path]

# %%
ports[0]
# Out:
#              date  risk_profile itemcode   weights tracking_code  \
# 0      2019-01-02             2  A273130  0.240000   ACT_BOND_D4
# 1      2019-01-02             2  A214980  0.240000       MM_PLUS
# 2      2019-01-02             2  A196230  0.207716       BOK_D.4
# 3      2019-01-02             2  A114260  0.100000        KTB_D3
# 4      2019-01-02             2  A122260  0.092284        BOK_D1
# ...           ...           ...      ...       ...           ...
# 19509  2021-05-06             4  A278540  0.240000       MSCI_KR
# 19510  2021-05-06             4  A157490  0.240000            SW
# 19511  2021-05-06             4  A266370  0.136000            IT
# 19512  2021-05-06             4  A069500  0.084000          K200
# 19513  2021-05-06             4  A114260  0.060000        KTB_D3
#
#                    itemname     price     volume  trading_amt_mln  \
# 0      KODEX 종합채권(AA-이상)액티브  104320.0    26468.0       858.104496
# 1            KODEX 단기채권PLUS  100050.0    10160.0       508.874866
# 2              KBSTAR 단기통안채  101423.0   393085.0     16568.430895
# 3               KODEX 국고채3년   55690.0     5449.0       251.127486
# 4               KOSEF 통안채1년   97761.0    42453.0     13238.397304
# ...                     ...       ...        ...              ...
# 19509   KODEX MSCI Korea TR   13810.0   401336.0     14336.127555
# 19510           TIGER 소프트웨어   16670.0   104451.0      2637.322487
# 19511              KODEX IT   20525.0    14105.0      1070.447295
# 19512             KODEX 200   42630.0  4079571.0    368064.948968
# 19513           KODEX 국고채3년   58060.0     2238.0       943.544023
#
#         asset_class
# 0      Fixed Income
# 1      Fixed Income
# 2      Fixed Income
# 3      Fixed Income
# 4      Fixed Income
# ...             ...
# 19509        Equity
# 19510        Equity
# 19511        Equity
# 19512        Equity
# 19513  Fixed Income
#
# [19514 rows x 10 columns]

# %%
ports[1]
# Out:
#            date  risk_profile itemcode   weights tracking_code  \
# 0    2021-05-07             2  A114260  0.240000        KTB_D3
# 1    2021-05-07             2  A122260  0.240000        BOK_D1
# 2    2021-05-07             2  A130730  0.240000            MM
# 3    2021-05-07             2  A196230  0.083929       BOK_D.4
# 4    2021-05-07             2  A273130  0.076071   ACT_BOND_D4
# ..          ...           ...      ...       ...           ...
# 543  2021-06-01             4  A157490  0.240000            SW
# 544  2021-06-01             4  A278540  0.240000       MSCI_KR
# 545  2021-06-01             4  A266370  0.136000            IT
# 546  2021-06-01             4  A292150  0.084000         TOP10
# 547  2021-06-01             4  A114260  0.060000        KTB_D3
#
#                  itemname   price  volume  trading_amt_mln   asset_class
# 0             KODEX 국고채3년   58055   11739       935.482379  Fixed Income
# 1             KOSEF 통안채1년  101330  658165     37510.592314  Fixed Income
# 2              KOSEF 단기자금  101100  176641     68231.636524  Fixed Income
# 3            KBSTAR 단기통안채  104445  936288     53069.439176  Fixed Income
# 4    KODEX 종합채권(AA-이상)액티브  108590   22802      1945.100057  Fixed Income
# ..                    ...     ...     ...              ...           ...
# 543           TIGER 소프트웨어   17690  148623      2490.713941        Equity
# 544   KODEX MSCI Korea TR   13735  280278      9454.867980        Equity
# 545              KODEX IT   20325   10876       799.389367        Equity
# 546           TIGER TOP10   14360  328759      4720.979240        Equity
# 547           KODEX 국고채3년   57990    2678       790.152822  Fixed Income
#
# [548 rows x 10 columns]

# %%
df = pd.concat(ports, axis=0)
df = df.reset_index(drop=True)

# %%
df
# Out:
#              date  risk_profile itemcode   weights tracking_code  \
# 0      2019-01-02             2  A273130  0.240000   ACT_BOND_D4
# 1      2019-01-02             2  A214980  0.240000       MM_PLUS
# 2      2019-01-02             2  A196230  0.207716       BOK_D.4
# 3      2019-01-02             2  A114260  0.100000        KTB_D3
# 4      2019-01-02             2  A122260  0.092284        BOK_D1
# ...           ...           ...      ...       ...           ...
# 20057  2021-06-01             4  A157490  0.240000            SW
# 20058  2021-06-01             4  A278540  0.240000       MSCI_KR
# 20059  2021-06-01             4  A266370  0.136000            IT
# 20060  2021-06-01             4  A292150  0.084000         TOP10
# 20061  2021-06-01             4  A114260  0.060000        KTB_D3
#
#                    itemname     price    volume  trading_amt_mln   asset_class
# 0      KODEX 종합채권(AA-이상)액티브  104320.0   26468.0       858.104496  Fixed Income
# 1            KODEX 단기채권PLUS  100050.0   10160.0       508.874866  Fixed Income
# 2              KBSTAR 단기통안채  101423.0  393085.0     16568.430895  Fixed Income
# 3               KODEX 국고채3년   55690.0    5449.0       251.127486  Fixed Income
# 4               KOSEF 통안채1년   97761.0   42453.0     13238.397304  Fixed Income
# ...                     ...       ...       ...              ...           ...
# 20057           TIGER 소프트웨어   17690.0  148623.0      2490.713941        Equity
# 20058   KODEX MSCI Korea TR   13735.0  280278.0      9454.867980        Equity
# 20059              KODEX IT   20325.0   10876.0       799.389367        Equity
# 20060           TIGER TOP10   14360.0  328759.0      4720.979240        Equity
# 20061           KODEX 국고채3년   57990.0    2678.0       790.152822  Fixed Income
#
# [20062 rows x 10 columns]

# %%
df.to_pickle(access_path + 'advised_portfolios.pkl')

# %%
import datetime
# BDay is business day, not birthday...
from pandas.tseries.offsets import BDay

today = datetime.datetime.today()
print(today - BDay(1))
# Out:
# 2021-05-31 18:35:34.740596
